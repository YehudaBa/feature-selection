# %%
! pip install -r ../requirements.txt
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import sys
import os

# Add project root to Python path
sys.path.append(os.path.abspath(os.path.join(os.path.dirname("__file__"), "..")))

# %%
from sklearn.datasets import fetch_openml
import pandas as pd

mnist = fetch_openml('mnist_784', version=1, as_frame=True)
df_openml = mnist.frame

# %%
from sklearn.datasets import fetch_openml
import pandas as pd

mnist = fetch_openml('mnist_784', version=1, as_frame=True)
df_openml = mnist.frame
df_openml["class"] = df_openml["class"].astype(int)
df_openml = df_openml[df_openml["class"].isin([0,1])].reset_index(drop = True)
df_openml.to_csv("../resources/openml_dataset.csv", index = False)

# %%
import config

# %%
config.input_path = "resources/openml_dataset.csv"
config.k_features = 30
config.percent_features = None
config.target_col = "class"
config.drop_cols = []
config.index_cols = []
config.time_complexities = {
"max_time_indexed_methods" : 94727755,
"max_time_non_indexed_methods" : 175798159}

config.benchmark_model_max_time = 3000000

config.model_type = "regression"

# %%
from feature_selection import FeatureSelection
fs = FeatureSelection()
fs.run()
# Out:
# Applying remove_zero_variance
# Applying random_forest_feature_selection
# Selected features: 309 out of 618 (50.0%)
# Applying lasso_feature_selection
# /Users/yehudabaharav/.pyenv/versions/3.11.10/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.709e+00, tolerance: 3.679e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/yehudabaharav/.pyenv/versions/3.11.10/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.663e+00, tolerance: 3.679e-01
#   model = cd_fast.enet_coordinate_descent(
# Final alpha used: 0.0005
# ...
